# %%
import requests
from bs4 import BeautifulSoup

data = requests.get('https://coinmarketcap.com/currencies/bitcoin/historical-data/?start=20130428&end=20171013') 

soup = BeautifulSoup(data._content, 'html.parser')

# %%
#print soup
# Out:
# <!DOCTYPE doctype html>
#
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en"> <!--<![endif]-->
# <head>
# <meta charset="utf-8">
# ...

# %%
from lxml import html
import requests


data1 = requests.get('https://coinmarketcap.com/currencies/bitcoin/historical-data/?start=20130428&end=20180303').content
data2= requests.get('https://coinmarketcap.com/currencies/ethereum/historical-data/?start=20130428&end=20180303').content
data3= requests.get('https://coinmarketcap.com/currencies/ripple/historical-data/?start=20130428&end=20180303').content

#https://coinmarketcap.com/currencies/ethereum/historical-data/
# data = requests.get('https://coinmarketcap.com/currencies/bitcoin/historical-data/?start=20130428&end=20180303').content
tree1 = html.fromstring(data1)
tree2 = html.fromstring(data2)

print tree
# Out:
# <Element html at 0x8717e58>

# %%
# note I did not want to sort out the logic to find the table so I cheated
# and selected the table with a specific data value
mytable1 = tree1.xpath('//td[contains(.,"4829.58")]/ancestor::table')[0]
mytable2= tree2.xpath('//td[contains(.,"303.50")]/ancestor::table')[0]

#303.50
for e in mytable2.iter(tag='tr'):
    print e.text_content()
# Out:
# Date
# Open
# High
# Low
# Close
# Volume
# Market Cap
#
#
# Mar 03, 2018
# 856.71
# 868.45
# 855.21
# 857.23
# 1,699,370,000
# 83,911,700,000
#
#
# Mar 02, 2018
# 871.76
# 876.38
# 852.42
# 856.85
# 1,894,420,000
# 85,368,100,000
#
#
# Mar 01, 2018
# 856.01
# 880.30
# 851.92
# 872.20
# 1,868,520,000
# 83,808,200,000
#
#
# Feb 28, 2018
# 877.93
# 890.11
# 855.12
# 855.20
# 1,963,980,000
# 85,936,400,000
#
#
# Feb 27, 2018
# 870.37
# 896.26
# 867.10
# 878.26
# 2,053,980,000
# 85,177,800,000
#
#
# Feb 26, 2018
# 845.28
# 880.39
# 842.32
# 869.32
# 2,044,480,000
# 82,705,400,000
#
#
# Feb 25, 2018
# 839.46
# 853.15
# 822.38
# 844.81
# 1,646,960,000
# 82,119,100,000
#
#
# Feb 24, 2018
# 861.59
# 879.53
# 818.55
# 840.51
# 1,926,580,000
# 84,266,700,000
#
#
# Feb 23, 2018
# 811.59
# 886.32
# 794.79
# 864.19
# 2,334,820,000
# 79,358,900,000
#
#
# Feb 22, 2018
# 849.26
# 875.93
# 802.67
# 812.85
# 2,150,370,000
# 83,025,800,000
#
#
# Feb 21, 2018
# 894.13
# 912.38
# 830.56
# 849.97
# ...
